# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
pppppppppppppppp000pppp;0p0;p0pppppppppppppppppppppppppp00000000000000000000000000000000000000000000000000000000000import seaborn as sns
# %matplotlib inline

# %%
train_df = pd.read_csv('data/train.csv')

# %%
train_df.head()
# Out:
#                  id                                                url  \
# 0  cacf8152e2d2ae60  http://static.panoramio.com/photos/original/70...
# 1  0a58358a2afd3e4e  http://lh6.ggpht.com/-igpT6wu0mIA/ROV8HnUuABI/...
# 2  6b2bb500b6a38aa0  http://lh6.ggpht.com/-vKr5G5MEusk/SR6r6SJi6mI/...
# 3  b399f09dee9c3c67  https://lh3.googleusercontent.com/-LOW2cjAqubA...
# 4  19ace29d77a5be66  https://lh5.googleusercontent.com/-tnmSXwQcWL8...
#
#    landmark_id
# 0         4676
# 1         6651
# 2        11284
# 3         8429
# 4         6231

# %% [markdown]
# # Number of classes

# %%
classes_count = len(set(train_df['landmark_id'].values))
classes_count
# Out:
# 14951

# %%
train_df['landmark_id'].hist()

# %%
train_df['landmark_id'].value_counts().hist()

# %% [markdown]
# # Distribution

# %% [markdown]
# ## 20 Most frequent landmarks

# %%
occ = pd.DataFrame(train_df['landmark_id'].value_counts().head(20))
occ.reset_index(inplace=True)
occ.columns = ['landmark_id','count']

# Plot the most frequent landmark_ids
plt.figure(figsize = (9, 8))
plt.title('Most frequent landmarks')
sns.set_color_codes("pastel")
sns.barplot(x="landmark_id", y="count", data=occ,
            label="Count")
plt.show()

# %% [markdown]
# ## 20 Least frequent landmarks

# %%
occ = pd.DataFrame(train_df['landmark_id'].value_counts().tail(20))
occ.reset_index(inplace=True)
occ.columns = ['landmark_id','count']

# Plot the least frequent landmark_ids
plt.figure(figsize = (9, 8))
plt.title('Least frequent landmarks')
sns.set_color_codes("pastel")
sns.barplot(x="landmark_id", y="count", data=occ,
            label="Count")
plt.show()
